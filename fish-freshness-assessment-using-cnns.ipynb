# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Segmentation_example_script.m
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/README.txt
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/license.txt
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00033.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00004.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00023.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00041.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00024.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00035.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00045.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00038.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00025.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00009.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00031.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00006.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00044.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00046.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00014.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00008.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00040.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00001.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00003.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00018.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00028.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00019.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00016.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00036.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00017.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00034.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00026.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00048.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00027.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00030.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00042.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00011.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00032.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00037.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00007.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00015.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00020.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00039.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00012.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00050.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00043.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00029.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00022.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00013.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00049.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00021.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00010.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00005.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00002.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Black Sea Sprat/00047.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/45.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/20.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/6.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/5.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/8.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/30.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/38.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/42.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/33.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/10.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/35.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/41.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/9.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/37.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/1.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/46.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/44.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/50.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/29.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/16.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/23.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/7.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/28.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/22.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/40.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/48.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/24.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/31.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/43.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/13.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/32.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/17.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/26.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/39.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/15.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/12.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/11.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/34.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/27.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/21.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/4.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/3.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/36.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/19.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/47.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/14.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/18.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/49.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/2.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Sea Bass/25.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00033.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00004.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00023.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00041.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00024.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00035.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00045.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00038.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00025.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00009.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00031.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00006.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00044.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00046.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00014.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00008.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00040.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00001.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00003.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00018.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00028.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00019.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00016.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00036.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00017.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00034.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00026.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00048.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00027.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00030.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00042.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00011.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00032.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00037.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00007.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00015.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00020.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00039.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00012.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00050.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00043.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00029.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00022.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00013.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00049.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00021.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00010.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00005.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00002.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Mullet/00047.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00004.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00023.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00024.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00025.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00009.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00006.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00014.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00008.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00001.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00003.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00018.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00028.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00019.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00016.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00017.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00026.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00027.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00030.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00011.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00007.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00015.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00020.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00012.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00029.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00022.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00013.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00021.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00010.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00005.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Trout/00002.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00033.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00004.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00023.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00041.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00024.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00035.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00045.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00038.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00025.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00009.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00031.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00006.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00044.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00046.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00014.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00008.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00040.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00001.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00003.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00018.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00028.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00019.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00016.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00036.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00017.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00034.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00026.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00048.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00027.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00030.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00042.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00011.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00032.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00037.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00007.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00015.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00020.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00039.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00012.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00050.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00043.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00029.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00022.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00013.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00049.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00021.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00010.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00005.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00002.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Striped Red Mullet/00047.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00033.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00004.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00023.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00041.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00024.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00035.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00045.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00038.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00025.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00009.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00031.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00006.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00044.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00046.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00014.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00008.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00040.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00001.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00003.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00018.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00028.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00019.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00016.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00036.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00017.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00034.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00026.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00048.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00027.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00030.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00042.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00011.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00032.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00037.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00007.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00015.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00020.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00039.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00012.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00050.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00043.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00029.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00022.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00013.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00049.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00021.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00010.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00005.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00002.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Shrimp/00047.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5577.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5538.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5561.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5583.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5568.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5537.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5540.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5543.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1481.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1480.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5534.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1489.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1478.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1476.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1465.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5564.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5565.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1483.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1488.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5581.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5535.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1477.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5551.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1482.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5533.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/WhatsApp Image 2019-04-25 at 15.33.13.jpeg
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1486.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5536.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5545.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5554.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5555.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5550.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5557.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5582.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5575.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5573.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5571.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5558.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1461.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1484.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5569.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5547.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5544.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1485.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1462.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1463.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5549.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/SAM_5552.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1479.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Red Sea Bream/100_1487.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00033.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00004.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00023.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00041.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00024.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00035.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00045.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00038.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00025.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00009.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00031.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00006.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00044.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00046.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00014.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00008.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00040.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00001.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00003.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00018.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00028.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00019.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00016.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00036.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00017.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00034.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00026.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00048.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00027.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00030.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00042.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00011.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00032.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00037.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00007.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00015.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00020.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00039.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00012.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00050.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00043.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00029.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00022.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00013.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00049.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00021.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00010.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00005.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00002.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Horse Mackerel/00047.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/45.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/20.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/6.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/5.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/8.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/30.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/38.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/42.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/33.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/10.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/35.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/41.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/9.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/37.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/1.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/46.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/44.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/50.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/29.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/16.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/23.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/7.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/28.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/22.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/40.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/48.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/24.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/31.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/43.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/13.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/21.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/32.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/17.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/26.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/39.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/15.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/12.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/11.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/34.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/27.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/4.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/3.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/36.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/19.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/47.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/14.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/18.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/49.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/2.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/NA_Fish_Dataset/Gilt Head Bream/25.JPG
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Segmentation_example_script.m
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/README.txt
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/license.txt
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00929.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00704.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00562.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00237.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00406.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00448.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00255.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00435.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00365.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00105.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00936.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00512.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00869.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00669.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00733.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00657.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00033.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00096.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00185.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00238.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00488.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00356.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00082.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00004.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00305.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00124.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00874.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00023.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00723.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00145.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00100.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00041.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00080.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00298.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00024.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00239.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00965.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00052.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00173.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00468.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00254.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00570.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00280.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00578.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00515.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00242.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00123.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00250.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00644.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00535.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Hourse Mackerel/Hourse Mackerel/00549.png
# ...
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00938.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00013.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00049.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00529.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00252.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00075.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00208.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00637.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00998.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00921.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00585.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00775.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00655.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00814.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00403.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00276.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00092.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00367.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00846.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00217.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00222.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00608.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00117.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00442.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00947.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00909.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00564.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00627.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00545.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00338.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00102.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00103.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00377.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00021.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00588.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00752.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00972.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00101.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00513.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00532.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00797.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00889.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00636.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00273.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00010.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00852.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00524.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00576.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00129.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00634.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00055.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00708.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00987.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00626.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00279.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00855.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00619.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00218.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00155.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00170.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00560.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00781.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00899.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00533.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00490.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00841.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00682.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00906.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00518.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00431.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00629.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00427.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00188.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00396.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00393.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00154.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00913.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00485.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00640.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00301.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00796.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00959.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00263.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00915.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00005.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00684.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00443.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00522.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00482.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00579.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00618.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00164.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00741.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00306.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00211.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00420.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00788.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00002.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00697.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00500.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00258.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00171.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00895.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00663.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00763.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00047.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00068.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00360.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00958.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00670.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00707.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00820.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00231.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00416.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00860.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00412.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00085.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00551.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00472.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00053.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00893.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00831.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00825.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00890.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00732.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00233.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00872.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00908.png
# /kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/Red Sea Bream/Red Sea Bream GT/00291.png

# %%
import shutil
from pathlib import Path

NON_FRESH_DIR = Path("/kaggle/working/non_fresh_synthetic/")
if NON_FRESH_DIR.exists():
    shutil.rmtree(NON_FRESH_DIR)
    print("Old non-fresh images deleted.")
NON_FRESH_DIR.mkdir(exist_ok=True)
print("Ready for new images.")
# Out:
# Ready for new images.

# %%
import random
import numpy as np
import pandas as pd
from pathlib import Path
from PIL import Image, ImageEnhance
import shutil

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

FISH_BASE = Path("/kaggle/input/datasets/crowww/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset/")
SPECIES = ['Hourse Mackerel', 'Black Sea Sprat', 'Sea Bass',
           'Red Mullet', 'Trout', 'Striped Red Mullet',
           'Shrimp', 'Gilt-Head Bream', 'Red Sea Bream']

# Collect fresh paths
fresh_paths = []
for species in SPECIES:
    species_dir = FISH_BASE / species / species
    if not species_dir.exists():
        species_dir = FISH_BASE / species
    for fpath in species_dir.glob("*.png"):
        if "GT" not in str(fpath):
            fresh_paths.append(str(fpath))
    for fpath in species_dir.glob("*.jpg"):
        if "GT" not in str(fpath):
            fresh_paths.append(str(fpath))

random.shuffle(fresh_paths)
fresh_paths = fresh_paths[:1000]
print(f"Fresh images selected: {len(fresh_paths)}")

# Delete old synthetic images
NON_FRESH_DIR = Path("/kaggle/working/non_fresh_synthetic/")
if NON_FRESH_DIR.exists():
    shutil.rmtree(NON_FRESH_DIR)
NON_FRESH_DIR.mkdir(exist_ok=True)

# Generate Non-Fresh with RANDOM varying degradation
print("Generating degraded Non-Fresh images with random variation...")
for i, fp in enumerate(fresh_paths):
    img = Image.open(fp).convert("RGB").resize((224, 224))
    arr = np.array(img, dtype=np.float32)

    # Random degradation strength — makes task harder
    red_boost   = random.uniform(1.05, 1.40)
    green_decay = random.uniform(0.50, 0.90)
    blue_decay  = random.uniform(0.45, 0.85)
    noise_level = random.randint(0, 30)

    arr[:, :, 0] = np.clip(arr[:, :, 0] * red_boost + noise_level, 0, 255)
    arr[:, :, 1] = np.clip(arr[:, :, 1] * green_decay, 0, 255)
    arr[:, :, 2] = np.clip(arr[:, :, 2] * blue_decay, 0, 255)

    # Add slight random noise to texture
    noise = np.random.normal(0, noise_level, arr.shape).astype(np.float32)
    arr = np.clip(arr + noise, 0, 255)

    degraded = Image.fromarray(arr.astype(np.uint8))

    # Random sharpness and contrast
    sharpness = random.uniform(0.2, 0.7)
    contrast  = random.uniform(0.5, 0.85)
    degraded = ImageEnhance.Sharpness(degraded).enhance(sharpness)
    degraded = ImageEnhance.Contrast(degraded).enhance(contrast)

    fpath_out = NON_FRESH_DIR / f"non_fresh_{i:04d}.jpg"
    degraded.save(fpath_out)
    if i % 100 == 0:
        print(f"  {i}/{len(fresh_paths)} done...")

# Build DataFrame
records = []
for fp in fresh_paths:
    records.append({"filepath": fp, "label": "Fresh"})
for i in range(len(fresh_paths)):
    records.append({"filepath": str(NON_FRESH_DIR / f"non_fresh_{i:04d}.jpg"),
                    "label": "Non-Fresh"})

df = pd.DataFrame(records)
df["label_idx"] = df["label"].map({"Fresh": 0, "Non-Fresh": 1})
print(f"\nTotal images: {len(df)}")
print(df["label"].value_counts().to_string())
# Out:
# Fresh images selected: 1000
# Generating degraded Non-Fresh images with random variation...
#   0/1000 done...
#   100/1000 done...
#   200/1000 done...
#   300/1000 done...
#   400/1000 done...
#   500/1000 done...
#   600/1000 done...
#   700/1000 done...
#   800/1000 done...
#   900/1000 done...
#
# Total images: 2000
# label
# Fresh        1000
# Non-Fresh    1000

# %%
# =============================================================================
# Fish Freshness Assessment Using Convolutional Neural Networks
# Machine Learning Course — Phase 2 Code Implementation
# =============================================================================
# This script is structured as a top-to-bottom runnable pipeline.
# Run on Kaggle Notebook (GPU T4 x2 recommended) or Google Colab.
# Dataset: https://www.kaggle.com/datasets/crowww/a-large-scale-fish-dataset
#          https://www.kaggle.com/datasets/tariqsays/fishy-dataset
# =============================================================================

# ─────────────────────────────────────────────────────────────────────────────
# SECTION 0: Imports and Configuration
# ─────────────────────────────────────────────────────────────────────────────

import os
import random
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from pathlib import Path
from datetime import datetime

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, callbacks, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, ResNet50, MobileNetV2
from tensorflow.keras.applications.vgg16 import preprocess_input as vgg_preprocess
from tensorflow.keras.applications.resnet50 import preprocess_input as resnet_preprocess
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input as mobilenet_preprocess

from sklearn.metrics import (
    classification_report, confusion_matrix,
    roc_auc_score, roc_curve, f1_score,
    precision_score, recall_score, accuracy_score
)
from sklearn.model_selection import train_test_split

import cv2
from PIL import Image

warnings.filterwarnings("ignore")

# ── Reproducibility seeds ──────────────────────────────────────────────────
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
os.environ["OMP_NUM_THREADS"] = "2"
os.environ["TF_NUM_INTEROP_THREADS"] = "2"
os.environ["TF_NUM_INTRAOP_THREADS"] = "2"
import gc
gc.collect()

# ── Global configuration ───────────────────────────────────────────────────
IMG_SIZE      = 224          # Input size for CNN and all transfer learning models
BATCH_SIZE    = 16
EPOCHS        = 20           # Max epochs; early stopping will likely trigger before
TL_EPOCHS     = 15           # Transfer learning fine-tuning epochs
LEARNING_RATE = 1e-3
TL_LR         = 1e-4         # Lower LR for fine-tuning transfer models
DROPOUT_RATE  = 0.5
NUM_CLASSES   = 2            # Fresh / Non-Fresh
CLASS_NAMES   = ["Fresh", "Non-Fresh"]

# ── Output directory for saving figures ───────────────────────────────────
OUTPUT_DIR = Path("./outputs")
OUTPUT_DIR.mkdir(exist_ok=True)

print("=" * 60)
print("Fish Freshness Assessment — CNN Implementation")
print(f"TensorFlow version : {tf.__version__}")
print(f"GPU available      : {len(tf.config.list_physical_devices('GPU')) > 0}")
print(f"Output directory   : {OUTPUT_DIR.resolve()}")
print("=" * 60)


# ─────────────────────────────────────────────────────────────────────────────
# SECTION 1: Dataset Loading
# ─────────────────────────────────────────────────────────────────────────────
# Expected directory structure (either layout works):
#
# Layout A (Kaggle fish freshness dataset):
#   /dataset/
#     fresh/      ← fresh fish images
#     non_fresh/  ← spoiled fish images
#
# Layout B (Large-scale fish dataset with GT folders):
#   /dataset/
#     NA Gilt-Head Bream/     ← each species subfolder contains images
#     ...
#   In this case, freshness labels come from a separate CSV.
#
# We support Layout A directly below. For Layout B, set USE_CSV_LABELS = True.
# ─────────────────────────────────────────────────────────────────────────────

# ── Adjust these paths to match your Kaggle / local setup ─────────────────
DATASET_DIR    = Path("/kaggle/working/non_fresh_synthetic/")  # not used anymore
USE_CSV_LABELS = False
# ── If dataset not found, build a synthetic demo dataset for testing ───────
def build_demo_dataset(base_path: Path, n_per_class: int = 60):
    """
    Create a minimal synthetic dataset so the script runs end-to-end
    without downloading anything. Images are random noise patches.
    Remove this function when using a real dataset.
    """
    print("[INFO] Building synthetic demo dataset for testing...")
    for cls in CLASS_NAMES:
        cls_dir = base_path / cls.lower().replace("-", "_")
        cls_dir.mkdir(parents=True, exist_ok=True)
        for i in range(n_per_class):
            arr = np.random.randint(0, 255, (IMG_SIZE, IMG_SIZE, 3), dtype=np.uint8)
            # Add slight class-specific tint so the model has a signal to learn
            if cls == "Fresh":
                arr[:, :, 1] = np.clip(arr[:, :, 1].astype(int) + 40, 0, 255)
            else:
                arr[:, :, 0] = np.clip(arr[:, :, 0].astype(int) + 40, 0, 255)
            img = Image.fromarray(arr)
            img.save(cls_dir / f"{cls.lower()}_{i:04d}.jpg")
    print(f"[INFO] Demo dataset created at: {base_path}")


# ── Build file-path dataframe ──────────────────────────────────────────────
def load_dataset_paths(dataset_dir: Path) -> pd.DataFrame:
    """
    Walk dataset_dir and return a DataFrame with columns:
        filepath (str), label (str), label_idx (int)
    Expects subfolders named 'fresh' and 'non_fresh' (or 'non-fresh').
    """
    records = []
    label_map = {}
    for folder in sorted(dataset_dir.iterdir()):
        if not folder.is_dir():
            continue
        name_lower = folder.name.lower()
        if "fresh" in name_lower and ("non" in name_lower or "not" in name_lower or "bad" in name_lower):
            label = "Non-Fresh"
        elif "fresh" in name_lower:
            label = "Fresh"
        else:
            print(f"  [SKIP] Unrecognized folder: {folder.name}")
            continue

        label_map[label] = label_map.get(label, len(label_map))
        exts = {".jpg", ".jpeg", ".png", ".bmp"}
        for fpath in folder.rglob("*"):
            if fpath.suffix.lower() in exts:
                records.append({"filepath": str(fpath), "label": label})

    df = pd.DataFrame(records)
    df["label_idx"] = df["label"].map({"Fresh": 0, "Non-Fresh": 1})
    return df


# ── Load or build dataset ──────────────────────────────────────────────────
#if not DATASET_DIR.exists() or not any(DATASET_DIR.iterdir()):
 #   DEMO_DIR = Path("./demo_dataset")
 #   build_demo_dataset(DEMO_DIR, n_per_class=80)
  #  DATASET_DIR = DEMO_DIR

# df is already built from the custom loader cell above
print(f"\n[Dataset] Total images found: {len(df)}")
print(df["label"].value_counts().to_string())

# ─────────────────────────────────────────────────────────────────────────────
# SECTION 2: Exploratory Data Analysis
# ─────────────────────────────────────────────────────────────────────────────

def plot_class_distribution(df: pd.DataFrame, save_path: Path):
    """Bar chart of class distribution."""
    counts = df["label"].value_counts()
    colors = ["#2E75B6", "#E04E3A"]
    fig, ax = plt.subplots(figsize=(6, 4))
    bars = ax.bar(counts.index, counts.values, color=colors, edgecolor="white", linewidth=1.2)
    for bar, val in zip(bars, counts.values):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 15,
                f"{val}\n({val / len(df) * 100:.1f}%)", ha="center", va="bottom", fontsize=10)
    ax.set_title("Class Distribution", fontsize=13, fontweight="bold")
    ax.set_xlabel("Class")
    ax.set_ylabel("Number of Images")
    ax.set_ylim(0, counts.max() * 1.2)
    plt.tight_layout()
    plt.savefig(save_path, dpi=150)
    plt.show()
    print(f"  Saved: {save_path}")

plot_class_distribution(df, OUTPUT_DIR / "fig01_class_distribution.png")


def show_sample_images(df: pd.DataFrame, save_path: Path, n_per_class: int = 4):
    """Display sample images for each class."""
    fig, axes = plt.subplots(2, n_per_class, figsize=(n_per_class * 3, 6))
    for row_idx, cls in enumerate(CLASS_NAMES):
        samples = df[df["label"] == cls].sample(min(n_per_class, len(df[df["label"] == cls])), random_state=SEED)
        for col_idx, (_, row) in enumerate(samples.iterrows()):
            img = Image.open(row["filepath"]).resize((IMG_SIZE, IMG_SIZE))
            axes[row_idx][col_idx].imshow(img)
            axes[row_idx][col_idx].axis("off")
            if col_idx == 0:
                axes[row_idx][col_idx].set_ylabel(cls, fontsize=12, fontweight="bold")
    plt.suptitle("Sample Images per Class", fontsize=14, fontweight="bold")
    plt.tight_layout()
    plt.savefig(save_path, dpi=150)
    plt.show()
    print(f"  Saved: {save_path}")

show_sample_images(df, OUTPUT_DIR / "fig02_sample_images.png")


# ─────────────────────────────────────────────────────────────────────────────
# SECTION 3: Train / Validation / Test Split
# ─────────────────────────────────────────────────────────────────────────────

# Stratified split: 70% train, 15% validation, 15% test
df_train, df_temp = train_test_split(df, test_size=0.30, random_state=SEED, stratify=df["label"])
df_val,   df_test = train_test_split(df_temp, test_size=0.50, random_state=SEED, stratify=df_temp["label"])

print(f"\n[Split] Train: {len(df_train)} | Val: {len(df_val)} | Test: {len(df_test)}")
for split_name, split_df in [("Train", df_train), ("Val", df_val), ("Test", df_test)]:
    print(f"  {split_name}: {split_df['label'].value_counts().to_dict()}")


# ─────────────────────────────────────────────────────────────────────────────
# SECTION 4: Data Preprocessing and Augmentation
# ─────────────────────────────────────────────────────────────────────────────

def preprocess_image(filepath: str, augment: bool = False) -> np.ndarray:
    """
    Load and preprocess a single image.
    - Resize to IMG_SIZE x IMG_SIZE
    - Normalize pixel values to [0, 1]
    """
    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0
    return img


def augment_image(img: tf.Tensor) -> tf.Tensor:
    """Apply random augmentation to a single image tensor."""
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_flip_up_down(img)
    img = tf.image.random_brightness(img, max_delta=0.15)
    img = tf.image.random_contrast(img, lower=0.85, upper=1.15)
    img = tf.image.random_saturation(img, lower=0.85, upper=1.15)
    # Random rotation via tfa (if available) or manual crop
    img = tf.image.random_crop(img, [int(IMG_SIZE * 0.9), int(IMG_SIZE * 0.9), 3])
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img


def make_dataset(df_subset: pd.DataFrame, augment: bool = False,
                 batch_size: int = BATCH_SIZE, shuffle: bool = False) -> tf.data.Dataset:
    """
    Build a tf.data.Dataset from a filepath/label DataFrame.
    Applies preprocessing and optional augmentation.
    """
    filepaths = df_subset["filepath"].values
    labels    = df_subset["label_idx"].values.astype(np.float32)

    ds = tf.data.Dataset.from_tensor_slices((filepaths, labels))
    if shuffle:
        ds = ds.shuffle(buffer_size=len(df_subset), seed=SEED)

    def load_and_preprocess(fp, label):
        img = preprocess_image(fp)
        if augment:
            img = augment_image(img)
        return img, label

    ds = ds.map(load_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return ds


# Build all three datasets
train_ds = make_dataset(df_train, augment=True,  shuffle=True)
val_ds   = make_dataset(df_val,   augment=False, shuffle=False)
test_ds  = make_dataset(df_test,  augment=False, shuffle=False)

print(f"\n[Dataset] Batches — Train: {len(train_ds)} | Val: {len(val_ds)} | Test: {len(test_ds)}")

# Visualize augmented images
def show_augmented_samples(df_subset: pd.DataFrame, save_path: Path, n: int = 8):
    """Show original vs augmented image pairs."""
    samples = df_subset.sample(n // 2, random_state=SEED)
    fig, axes = plt.subplots(2, n // 2, figsize=(n // 2 * 3, 6))
    for i, (_, row) in enumerate(samples.iterrows()):
        img = preprocess_image(row["filepath"])
        img_aug = augment_image(img)
        axes[0][i].imshow(img.numpy())
        axes[0][i].set_title(row["label"], fontsize=9)
        axes[0][i].axis("off")
        axes[1][i].imshow(img_aug.numpy())
        axes[1][i].set_title("Augmented", fontsize=9)
        axes[1][i].axis("off")
    axes[0][0].set_ylabel("Original", fontsize=10, fontweight="bold")
    axes[1][0].set_ylabel("Augmented", fontsize=10, fontweight="bold")
    plt.suptitle("Data Augmentation Examples", fontsize=13, fontweight="bold")
    plt.tight_layout()
    plt.savefig(save_path, dpi=150)
    plt.show()
    print(f"  Saved: {save_path}")

show_augmented_samples(df_train, OUTPUT_DIR / "fig03_augmentation_examples.png")


# ─────────────────────────────────────────────────────────────────────────────
# SECTION 5: Custom CNN Architecture
# ─────────────────────────────────────────────────────────────────────────────

def build_custom_cnn(input_shape=(IMG_SIZE, IMG_SIZE, 3), num_classes=1) -> keras.Model:
    """
    Custom CNN with 4 convolutional blocks, BatchNorm, and Dropout.
    Designed specifically for binary image classification.

    Architecture:
        Input → [Conv → BN → ReLU → MaxPool] x4 → GAP → Dense → Dropout → Output
    """
    inputs = keras.Input(shape=input_shape, name="input")

    # ── Block 1: 32 filters ─────────────────────────────────────────────────
    x = layers.Conv2D(32, (3, 3), padding="same", use_bias=False, name="block1_conv")(inputs)
    x = layers.BatchNormalization(name="block1_bn")(x)
    x = layers.Activation("relu", name="block1_relu")(x)
    x = layers.MaxPooling2D((2, 2), name="block1_pool")(x)

    # ── Block 2: 64 filters ─────────────────────────────────────────────────
    x = layers.Conv2D(64, (3, 3), padding="same", use_bias=False, name="block2_conv")(x)
    x = layers.BatchNormalization(name="block2_bn")(x)
    x = layers.Activation("relu", name="block2_relu")(x)
    x = layers.MaxPooling2D((2, 2), name="block2_pool")(x)

    # ── Block 3: 128 filters ────────────────────────────────────────────────
    x = layers.Conv2D(128, (3, 3), padding="same", use_bias=False, name="block3_conv")(x)
    x = layers.BatchNormalization(name="block3_bn")(x)
    x = layers.Activation("relu", name="block3_relu")(x)
    x = layers.MaxPooling2D((2, 2), name="block3_pool")(x)

    # ── Block 4: 256 filters ────────────────────────────────────────────────
    x = layers.Conv2D(256, (3, 3), padding="same", use_bias=False, name="block4_conv")(x)
    x = layers.BatchNormalization(name="block4_bn")(x)
    x = layers.Activation("relu", name="block4_relu")(x)
    x = layers.MaxPooling2D((2, 2), name="block4_pool")(x)

    # ── Global Average Pooling instead of Flatten (reduces overfitting) ─────
    x = layers.GlobalAveragePooling2D(name="gap")(x)

    # ── Dense classifier ────────────────────────────────────────────────────
    x = layers.Dense(512, activation="relu",
                     kernel_regularizer=regularizers.l2(1e-4), name="dense1")(x)
    x = layers.Dropout(DROPOUT_RATE, name="dropout1")(x)
    x = layers.Dense(128, activation="relu",
                     kernel_regularizer=regularizers.l2(1e-4), name="dense2")(x)
    x = layers.Dropout(0.3, name="dropout2")(x)

    # ── Output layer: Sigmoid for binary classification ──────────────────────
    outputs = layers.Dense(1, activation="sigmoid", name="output")(x)

    model = keras.Model(inputs, outputs, name="CustomCNN")
    return model


custom_cnn = build_custom_cnn()
custom_cnn.summary()


# ─────────────────────────────────────────────────────────────────────────────
# SECTION 6: Training Utilities (Callbacks, Compile, History Plotting)
# ─────────────────────────────────────────────────────────────────────────────

def get_callbacks(model_name: str, patience: int = 8) -> list:
    """Return a standard set of training callbacks."""
    return [
        callbacks.ModelCheckpoint(
            filepath=str(OUTPUT_DIR / f"{model_name}_best.keras"),
            monitor="val_loss",
            save_best_only=True,
            verbose=1
        ),
        callbacks.EarlyStopping(
            monitor="val_loss",
            patience=patience,
            restore_best_weights=True,
            verbose=1
        ),
        callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=4,
            min_lr=1e-7,
            verbose=1
        ),
    ]


def compile_model(model: keras.Model, lr: float = LEARNING_RATE) -> keras.Model:
    """Compile a binary classification model with standard settings."""
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            keras.metrics.Precision(name="precision"),
            keras.metrics.Recall(name="recall"),
            keras.metrics.AUC(name="auc")
        ]
    )
    return model


def plot_training_history(history, model_name: str, save_dir: Path):
    """Plot accuracy and loss curves for a training history object."""
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    # ── Accuracy ────────────────────────────────────────────────────────────
    axes[0].plot(history.history["accuracy"],     label="Train Accuracy", color="#2E75B6", linewidth=2)
    axes[0].plot(history.history["val_accuracy"], label="Val Accuracy",   color="#E04E3A", linewidth=2)
    axes[0].set_title(f"{model_name} — Accuracy", fontsize=12, fontweight="bold")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Accuracy")
    axes[0].legend()
    axes[0].grid(alpha=0.3)

    # ── Loss ────────────────────────────────────────────────────────────────
    axes[1].plot(history.history["loss"],     label="Train Loss", color="#2E75B6", linewidth=2)
    axes[1].plot(history.history["val_loss"], label="Val Loss",   color="#E04E3A", linewidth=2)
    axes[1].set_title(f"{model_name} — Loss", fontsize=12, fontweight="bold")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Loss")
    axes[1].legend()
    axes[1].grid(alpha=0.3)

    plt.tight_layout()
    fig_path = save_dir / f"fig_history_{model_name.lower().replace(' ', '_')}.png"
    plt.savefig(fig_path, dpi=150)
    plt.show()
    print(f"  Saved: {fig_path}")


# ─────────────────────────────────────────────────────────────────────────────
# SECTION 7: Train Custom CNN
# ─────────────────────────────────────────────────────────────────────────────

print("\n" + "=" * 60)
print("Training Custom CNN...")
print("=" * 60)

custom_cnn = compile_model(custom_cnn, lr=LEARNING_RATE)

history_custom = custom_cnn.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=get_callbacks("CustomCNN"),
    verbose=1
)

plot_training_history(history_custom, "Custom CNN", OUTPUT_DIR)


# ─────────────────────────────────────────────────────────────────────────────
# SECTION 8: Transfer Learning Models
# ─────────────────────────────────────────────────────────────────────────────

def build_transfer_model(base_arch: str, input_shape=(IMG_SIZE, IMG_SIZE, 3)) -> keras.Model:
    """
    Build a transfer learning model by attaching a custom classification head
    to a pre-trained base (VGG16, ResNet50, or MobileNetV2).

    Strategy:
        Phase 1 — Freeze base, train only the new head (fast convergence)
        Phase 2 — Unfreeze last N layers, fine-tune with low LR
    """
    arch_map = {
        "vgg16":      (VGG16,      vgg_preprocess,     -6),   # unfreeze last 2 blocks
        "resnet50":   (ResNet50,   resnet_preprocess,  -15),  # unfreeze last residual block
        "mobilenetv2":(MobileNetV2, mobilenet_preprocess, -20),
    }
    BaseClass, preprocess_fn, finetune_layer = arch_map[base_arch.lower()]

    # ── Load pre-trained base without top classifier ─────────────────────────
    base = BaseClass(
        weights="imagenet",
        include_top=False,
        input_shape=input_shape
    )
    base.trainable = False  # Freeze all base layers initially

    # ── Add preprocessing + custom head ──────────────────────────────────────
    inputs = keras.Input(shape=input_shape, name="input")
    # Note: preprocess_fn scales to model's expected range (e.g., [-1, 1] for MobileNet)
    x = keras.layers.Lambda(lambda img: preprocess_fn(img * 255.0),
                            name="preprocess")(inputs)
    x = base(x, training=False)
    x = layers.GlobalAveragePooling2D(name="gap")(x)
    x = layers.Dense(256, activation="relu",
                     kernel_regularizer=regularizers.l2(1e-4), name="dense1")(x)
    x = layers.Dropout(0.4, name="dropout")(x)
    outputs = layers.Dense(1, activation="sigmoid", name="output")(x)

    model = keras.Model(inputs, outputs, name=f"TL_{base_arch.upper()}")
    model._base_model = base
    model._finetune_layer = finetune_layer
    model._preprocess_fn = preprocess_fn
    return model


def finetune_model(model: keras.Model) -> keras.Model:
    """Unfreeze the top layers of the base model for fine-tuning."""
    base = model._base_model
    base.trainable = True
    # Freeze all layers except the last N
    finetune_from = model._finetune_layer
    for layer in base.layers[:finetune_from]:
        layer.trainable = False
    print(f"  Fine-tuning: {sum(not l.trainable for l in base.layers)} frozen, "
          f"{sum(l.trainable for l in base.layers)} trainable layers in base")
    return model


def train_transfer_model(arch_name: str) -> tuple:
    """Full two-phase training for a transfer learning model."""
    print(f"\n{'=' * 60}")
    print(f"Transfer Learning: {arch_name.upper()}")
    print(f"{'=' * 60}")

    model = build_transfer_model(arch_name)
    model = compile_model(model, lr=LEARNING_RATE)

    # Phase 1: Train head only
    print(f"\n[Phase 1] Training classification head (base frozen)...")
    history_phase1 = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=20,
        callbacks=get_callbacks(f"TL_{arch_name}_phase1", patience=5),
        verbose=1
    )

    # Phase 2: Unfreeze and fine-tune
    print(f"\n[Phase 2] Fine-tuning unfrozen base layers...")
    model = finetune_model(model)
    model = compile_model(model, lr=TL_LR)

    history_phase2 = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=TL_EPOCHS,
        callbacks=get_callbacks(f"TL_{arch_name}_best", patience=6),
        verbose=1
    )

    # Merge histories for plotting
    combined_history_dict = {}
    for key in history_phase1.history:
        combined_history_dict[key] = (
            history_phase1.history[key] + history_phase2.history.get(key, [])
        )

    class CombinedHistory:
        def __init__(self, d): self.history = d
    combined_history = CombinedHistory(combined_history_dict)

    plot_training_history(combined_history, arch_name.upper(), OUTPUT_DIR)
    return model, combined_history


# Train all three transfer learning models
model_vgg16,       history_vgg16       = train_transfer_model("vgg16")
model_resnet50,    history_resnet50    = train_transfer_model("resnet50")
model_mobilenetv2, history_mobilenetv2 = train_transfer_model("mobilenetv2")


# ─────────────────────────────────────────────────────────────────────────────
# SECTION 9: Model Evaluation
# ─────────────────────────────────────────────────────────────────────────────

def evaluate_model(model: keras.Model, test_dataset: tf.data.Dataset,
                   model_name: str) -> dict:
    """
    Evaluate a trained model on the test set.
    Returns a dict with accuracy, precision, recall, F1, AUC.
    """
    y_true, y_pred_prob = [], []
    for images, labels in test_dataset:
        preds = model.predict(images, verbose=0).flatten()
        y_pred_prob.extend(preds.tolist())
        y_true.extend(labels.numpy().tolist())

    y_true      = np.array(y_true).astype(int)
    y_pred_prob = np.array(y_pred_prob)
    y_pred      = (y_pred_prob >= 0.5).astype(int)

    results = {
        "model":     model_name,
        "accuracy":  round(accuracy_score(y_true, y_pred), 4),
        "precision": round(precision_score(y_true, y_pred, zero_division=0), 4),
        "recall":    round(recall_score(y_true, y_pred, zero_division=0), 4),
        "f1":        round(f1_score(y_true, y_pred, zero_division=0), 4),
        "auc":       round(roc_auc_score(y_true, y_pred_prob) if len(np.unique(y_true)) > 1 else 0.5, 4),
        "y_true":    y_true,
        "y_pred":    y_pred,
        "y_pred_prob": y_pred_prob
    }
    return results


# Evaluate all models
print("\n[Evaluating all models on test set...]")
results_custom   = evaluate_model(custom_cnn,        test_ds, "Custom CNN")
results_vgg16    = evaluate_model(model_vgg16,        test_ds, "VGG16")
results_resnet50 = evaluate_model(model_resnet50,     test_ds, "ResNet50")
results_mobilenet= evaluate_model(model_mobilenetv2,  test_ds, "MobileNetV2")

all_results = [results_custom, results_vgg16, results_resnet50, results_mobilenet]


# ─────────────────────────────────────────────────────────────────────────────
# SECTION 10: Confusion Matrix
# ─────────────────────────────────────────────────────────────────────────────

def plot_confusion_matrix(y_true: np.ndarray, y_pred: np.ndarray,
                           model_name: str, class_names: list, save_dir: Path):
    """Plot and save a normalized confusion matrix heatmap."""
    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    for ax, data, title in zip(axes, [cm, cm_norm], ["Counts", "Normalized"]):
        fmt = "d" if title == "Counts" else ".2f"
        sns.heatmap(data, annot=True, fmt=fmt, cmap="Blues", ax=ax,
                    xticklabels=class_names, yticklabels=class_names,
                    linewidths=0.5, linecolor="white")
        ax.set_title(f"{model_name} — Confusion Matrix ({title})", fontsize=11, fontweight="bold")
        ax.set_xlabel("Predicted Label")
        ax.set_ylabel("True Label")
    plt.tight_layout()
    fname = save_dir / f"fig_cm_{model_name.lower().replace(' ', '_')}.png"
    plt.savefig(fname, dpi=150)
    plt.show()
    print(f"  Saved: {fname}")


for res in all_results:
    plot_confusion_matrix(res["y_true"], res["y_pred"], res["model"], CLASS_NAMES, OUTPUT_DIR)


# ─────────────────────────────────────────────────────────────────────────────
# SECTION 11: Classification Report
# ─────────────────────────────────────────────────────────────────────────────

print("\n" + "=" * 60)
print("Classification Reports")
print("=" * 60)

for res in all_results:
    print(f"\n--- {res['model']} ---")
    print(classification_report(res["y_true"], res["y_pred"], target_names=CLASS_NAMES))


# ─────────────────────────────────────────────────────────────────────────────
# SECTION 12: Model Comparison Table
# ─────────────────────────────────────────────────────────────────────────────

comparison_df = pd.DataFrame([{
    "Model":     r["model"],
    "Accuracy":  r["accuracy"],
    "Precision": r["precision"],
    "Recall":    r["recall"],
    "F1-Score":  r["f1"],
    "AUC-ROC":   r["auc"],
} for r in all_results])

print("\n" + "=" * 60)
print("Model Comparison Table")
print("=" * 60)
print(comparison_df.to_string(index=False))
comparison_df.to_csv(OUTPUT_DIR / "table_model_comparison.csv", index=False)

# Visual comparison bar chart
def plot_model_comparison(df: pd.DataFrame, save_path: Path):
    metrics = ["Accuracy", "Precision", "Recall", "F1-Score", "AUC-ROC"]
    x = np.arange(len(df))
    width = 0.15
    colors = ["#2E75B6", "#E04E3A", "#2ECC71", "#F39C12", "#9B59B6"]

    fig, ax = plt.subplots(figsize=(13, 5))
    for i, (metric, color) in enumerate(zip(metrics, colors)):
        bars = ax.bar(x + i * width, df[metric], width, label=metric, color=color, alpha=0.85)
        for bar in bars:
            ax.text(bar.get_x() + bar.get_width() / 2,
                    bar.get_height() + 0.005,
                    f"{bar.get_height():.2f}",
                    ha="center", va="bottom", fontsize=7)

    ax.set_xlabel("Model")
    ax.set_ylabel("Score")
    ax.set_title("Model Performance Comparison", fontsize=13, fontweight="bold")
    ax.set_xticks(x + width * 2)
    ax.set_xticklabels(df["Model"])
    ax.set_ylim(0, 1.1)
    ax.legend(loc="lower right", fontsize=9)
    ax.grid(axis="y", alpha=0.3)
    plt.tight_layout()
    plt.savefig(save_path, dpi=150)
    plt.show()
    print(f"  Saved: {save_path}")

plot_model_comparison(comparison_df, OUTPUT_DIR / "fig_model_comparison.png")


# ─────────────────────────────────────────────────────────────────────────────
# SECTION 13: ROC Curves (All Models on One Plot)
# ─────────────────────────────────────────────────────────────────────────────

def plot_roc_curves(all_results: list, save_path: Path):
    """Plot ROC curves for all models on the same axes."""
    fig, ax = plt.subplots(figsize=(7, 6))
    colors = ["#2E75B6", "#E04E3A", "#2ECC71", "#F39C12"]

    for res, color in zip(all_results, colors):
        if len(np.unique(res["y_true"])) > 1:
            fpr, tpr, _ = roc_curve(res["y_true"], res["y_pred_prob"])
            ax.plot(fpr, tpr, color=color, linewidth=2,
                    label=f"{res['model']} (AUC = {res['auc']:.3f})")

    ax.plot([0, 1], [0, 1], "k--", linewidth=1, label="Random Classifier")
    ax.set_xlabel("False Positive Rate")
    ax.set_ylabel("True Positive Rate")
    ax.set_title("ROC Curves — All Models", fontsize=13, fontweight="bold")
    ax.legend(loc="lower right")
    ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(save_path, dpi=150)
    plt.show()
    print(f"  Saved: {save_path}")

plot_roc_curves(all_results, OUTPUT_DIR / "fig_roc_curves.png")


# ─────────────────────────────────────────────────────────────────────────────
# SECTION 14: Grad-CAM Visualization
# ─────────────────────────────────────────────────────────────────────────────

def get_gradcam_heatmap(model: keras.Model, img_array: np.ndarray,
                         last_conv_layer_name: str) -> np.ndarray:
    """
    Generate a Grad-CAM heatmap for a given image.
    Grad-CAM uses the gradient of the predicted class score with respect to
    the last convolutional layer to highlight discriminative regions.

    Reference: Selvaraju et al. (2017), ICCV.
    """
    # Build a model that outputs both the last conv layer activations and predictions
    grad_model = keras.Model(
        inputs=model.inputs,
        outputs=[model.get_layer(last_conv_layer_name).output, model.output]
    )

    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array[np.newaxis], training=False)
        # For binary classification, the loss is the prediction itself
        loss = predictions[:, 0]

    # Gradient of the class score w.r.t. the conv layer outputs
    grads = tape.gradient(loss, conv_outputs)

    # Pool gradients over spatial dimensions → importance weights
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # Weight the feature maps by their importance
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / (tf.math.reduce_max(heatmap) + 1e-8)
    return heatmap.numpy()


def overlay_gradcam(original_img: np.ndarray, heatmap: np.ndarray,
                     alpha: float = 0.4) -> np.ndarray:
    """Overlay Grad-CAM heatmap on original image."""
    heatmap_resized = cv2.resize(heatmap, (original_img.shape[1], original_img.shape[0]))
    heatmap_colored = cm.jet(heatmap_resized)[:, :, :3]  # Drop alpha channel
    heatmap_colored = (heatmap_colored * 255).astype(np.uint8)
    original_rgb = (original_img * 255).astype(np.uint8)
    overlaid = cv2.addWeighted(original_rgb, 1 - alpha, heatmap_colored, alpha, 0)
    return overlaid


def plot_gradcam_grid(model: keras.Model, df_test: pd.DataFrame,
                       last_conv_name: str, model_name: str,
                       save_path: Path, n: int = 6):
    """
    Plot a grid of original images with Grad-CAM overlays for
    correctly and incorrectly classified examples.
    """
    samples = df_test.sample(min(n, len(df_test)), random_state=SEED)
    fig, axes = plt.subplots(2, n, figsize=(n * 3, 6))

    for col_idx, (_, row) in enumerate(samples.iterrows()):
        img = preprocess_image(row["filepath"]).numpy()
        heatmap = get_gradcam_heatmap(model, img, last_conv_name)
        overlaid = overlay_gradcam(img, heatmap)
        pred_prob = model.predict(img[np.newaxis], verbose=0)[0, 0]
        pred_label = CLASS_NAMES[int(pred_prob >= 0.5)]
        true_label = row["label"]
        color = "green" if pred_label == true_label else "red"

        axes[0][col_idx].imshow(img)
        axes[0][col_idx].set_title(f"True: {true_label}", fontsize=8)
        axes[0][col_idx].axis("off")

        axes[1][col_idx].imshow(overlaid)
        axes[1][col_idx].set_title(f"Pred: {pred_label}\n({pred_prob:.2f})",
                                    fontsize=8, color=color)
        axes[1][col_idx].axis("off")

    axes[0][0].set_ylabel("Original", fontsize=9, fontweight="bold")
    axes[1][0].set_ylabel("Grad-CAM", fontsize=9, fontweight="bold")
    plt.suptitle(f"Grad-CAM Visualizations — {model_name}", fontsize=12, fontweight="bold")
    plt.tight_layout()
    plt.savefig(save_path, dpi=150)
    plt.show()
    print(f"  Saved: {save_path}")


# Apply Grad-CAM to Custom CNN (last conv layer name: "block4_conv")
# and best transfer model (ResNet50 last conv: "conv5_block3_out")
try:
    plot_gradcam_grid(custom_cnn, df_test, "block4_conv",
                      "Custom CNN", OUTPUT_DIR / "fig_gradcam_custom_cnn.png")
except Exception as e:
    print(f"[WARN] Grad-CAM failed for Custom CNN: {e}")

try:
    plot_gradcam_grid(model_resnet50, df_test, "conv5_block3_out",
                      "ResNet50", OUTPUT_DIR / "fig_gradcam_resnet50.png")
except Exception as e:
    print(f"[WARN] Grad-CAM failed for ResNet50: {e}")


# ─────────────────────────────────────────────────────────────────────────────
# SECTION 15: Error Analysis
# ─────────────────────────────────────────────────────────────────────────────

def plot_error_analysis(model: keras.Model, df_test: pd.DataFrame,
                          model_name: str, save_path: Path, n: int = 8):
    """
    Display the model's most confident wrong predictions.
    Helps identify systematic failure modes.
    """
    errors = []
    for _, row in df_test.iterrows():
        img = preprocess_image(row["filepath"]).numpy()
        pred_prob = float(model.predict(img[np.newaxis], verbose=0)[0, 0])
        pred_label = CLASS_NAMES[int(pred_prob >= 0.5)]
        true_label = row["label"]
        if pred_label != true_label:
            confidence = pred_prob if pred_prob >= 0.5 else 1 - pred_prob
            errors.append({
                "filepath": row["filepath"],
                "true_label": true_label,
                "pred_label": pred_label,
                "confidence": confidence,
                "pred_prob": pred_prob
            })

    if not errors:
        print(f"  No errors found for {model_name}.")
        return

    errors = sorted(errors, key=lambda x: x["confidence"], reverse=True)[:n]
    ncols = min(n, 4)
    nrows = (len(errors) + ncols - 1) // ncols
    fig, axes = plt.subplots(nrows, ncols, figsize=(ncols * 3, nrows * 3.5))
    axes = np.array(axes).reshape(-1) if nrows * ncols > 1 else [axes]

    for i, err in enumerate(errors):
        img = preprocess_image(err["filepath"]).numpy()
        axes[i].imshow(img)
        axes[i].set_title(
            f"True: {err['true_label']}\nPred: {err['pred_label']} ({err['confidence']:.2f})",
            fontsize=8, color="red"
        )
        axes[i].axis("off")

    for j in range(len(errors), len(axes)):
        axes[j].axis("off")

    plt.suptitle(f"Error Analysis — {model_name} (Most Confident Mistakes)", fontsize=11, fontweight="bold")
    plt.tight_layout()
    plt.savefig(save_path, dpi=150)
    plt.show()
    print(f"  Saved: {save_path}")
    print(f"  Total errors: {len(errors)} of {len(df_test)}")

plot_error_analysis(custom_cnn, df_test, "Custom CNN",
                    OUTPUT_DIR / "fig_error_analysis_custom_cnn.png")
plot_error_analysis(model_resnet50, df_test, "ResNet50",
                    OUTPUT_DIR / "fig_error_analysis_resnet50.png")


# ─────────────────────────────────────────────────────────────────────────────
# SECTION 16: Save Models and Final Summary
# ─────────────────────────────────────────────────────────────────────────────

print("\n[Saving models...]")
custom_cnn.save(OUTPUT_DIR / "model_custom_cnn.keras")
model_vgg16.save(OUTPUT_DIR / "model_vgg16.keras")
model_resnet50.save(OUTPUT_DIR / "model_resnet50.keras")
model_mobilenetv2.save(OUTPUT_DIR / "model_mobilenetv2.keras")
print("  All models saved.")

# ── Final summary ──────────────────────────────────────────────────────────
print("\n" + "=" * 60)
print("FINAL RESULTS SUMMARY")
print("=" * 60)
print(comparison_df.to_string(index=False))

best_model_name = comparison_df.loc[comparison_df["F1-Score"].idxmax(), "Model"]
best_f1 = comparison_df["F1-Score"].max()
print(f"\n  Best model by F1-Score: {best_model_name} (F1 = {best_f1:.4f})")
print(f"\n  All output figures saved to: {OUTPUT_DIR.resolve()}")
print("=" * 60)
print("Done!")
# Out:
# 2026-06-27 21:25:16.348394: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1782595516.529418      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1782595516.578808      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1782595517.016821      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782595517.016866      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782595517.016869      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782595517.016872      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ============================================================
# Fish Freshness Assessment — CNN Implementation
# TensorFlow version : 2.19.0
# GPU available      : True
# Output directory   : /kaggle/working/outputs
# ============================================================
#
# [Dataset] Total images found: 2000
# label
# Fresh        1000
# Non-Fresh    1000
#   Saved: outputs/fig01_class_distribution.png
#   Saved: outputs/fig02_sample_images.png
#
# [Split] Train: 1400 | Val: 300 | Test: 300
#   Train: {'Fresh': 700, 'Non-Fresh': 700}
#   Val: {'Non-Fresh': 150, 'Fresh': 150}
#   Test: {'Non-Fresh': 150, 'Fresh': 150}
# I0000 00:00:1782595531.496916      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# [Dataset] Batches — Train: 88 | Val: 19 | Test: 19
#   Saved: outputs/fig03_augmentation_examples.png
# Model: "CustomCNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv (Conv2D)            │ (None, 224, 224, 32)   │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_bn (BatchNormalization)  │ (None, 224, 224, 32)   │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_relu (Activation)        │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv (Conv2D)            │ (None, 112, 112, 64)   │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_bn (BatchNormalization)  │ (None, 112, 112, 64)   │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_relu (Activation)        │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv (Conv2D)            │ (None, 56, 56, 128)    │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_bn (BatchNormalization)  │ (None, 56, 56, 128)    │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_relu (Activation)        │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv (Conv2D)            │ (None, 28, 28, 256)    │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_bn (BatchNormalization)  │ (None, 28, 28, 256)    │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_relu (Activation)        │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gap (GlobalAveragePooling2D)    │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense1 (Dense)                  │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout1 (Dropout)              │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense2 (Dense)                  │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout2 (Dropout)              │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 587,233 (2.24 MB)
#  Trainable params: 586,273 (2.24 MB)
#  Non-trainable params: 960 (3.75 KB)
# ============================================================
# Training Custom CNN...
# ============================================================
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782595539.761499      66 service.cc:152] XLA service 0x7be3c8002e80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1782595539.761546      66 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1782595540.493199      66 cuda_dnn.cc:529] Loaded cuDNN version 91002
#  5/88 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7556 - auc: 0.8889 - loss: 0.4951 - precision: 0.8479 - recall: 0.6681
# I0000 00:00:1782595546.321249      66 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9281 - auc: 0.9766 - loss: 0.2398 - precision: 0.9462 - recall: 0.9054
# Epoch 1: val_loss improved from None to 1.78264, saving model to outputs/CustomCNN_best.keras
#
# Epoch 1: finished saving model to outputs/CustomCNN_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 21s 126ms/step - accuracy: 0.9586 - auc: 0.9888 - loss: 0.1731 - precision: 0.9679 - recall: 0.9486 - val_accuracy: 0.5000 - val_auc: 0.7395 - val_loss: 1.7826 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 2/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9838 - auc: 0.9988 - loss: 0.0807 - precision: 0.9837 - recall: 0.9832
# Epoch 2: val_loss improved from 1.78264 to 1.62980, saving model to outputs/CustomCNN_best.keras
#
# Epoch 2: finished saving model to outputs/CustomCNN_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9764 - auc: 0.9981 - loss: 0.0973 - precision: 0.9771 - recall: 0.9757 - val_accuracy: 0.5000 - val_auc: 0.8774 - val_loss: 1.6298 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 3/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9925 - auc: 0.9994 - loss: 0.0655 - precision: 0.9946 - recall: 0.9900
# Epoch 3: val_loss did not improve from 1.62980
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9900 - auc: 0.9991 - loss: 0.0717 - precision: 0.9928 - recall: 0.9871 - val_accuracy: 0.5000 - val_auc: 0.8415 - val_loss: 2.0363 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 4/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9934 - auc: 0.9998 - loss: 0.0521 - precision: 0.9875 - recall: 0.9987
# Epoch 4: val_loss improved from 1.62980 to 0.17354, saving model to outputs/CustomCNN_best.keras
#
# Epoch 4: finished saving model to outputs/CustomCNN_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9900 - auc: 0.9973 - loss: 0.0771 - precision: 0.9942 - recall: 0.9857 - val_accuracy: 0.9567 - val_auc: 1.0000 - val_loss: 0.1735 - val_precision: 0.9202 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 5/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9675 - auc: 0.9915 - loss: 0.1480 - precision: 0.9516 - recall: 0.9835
# Epoch 5: val_loss did not improve from 0.17354
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9800 - auc: 0.9965 - loss: 0.0982 - precision: 0.9773 - recall: 0.9829 - val_accuracy: 0.8633 - val_auc: 0.9996 - val_loss: 0.3620 - val_precision: 0.7853 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 6/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9891 - auc: 0.9987 - loss: 0.0697 - precision: 0.9909 - recall: 0.9884
# Epoch 6: val_loss did not improve from 0.17354
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9857 - auc: 0.9973 - loss: 0.0793 - precision: 0.9857 - recall: 0.9857 - val_accuracy: 0.9133 - val_auc: 1.0000 - val_loss: 0.2379 - val_precision: 0.8523 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 7/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9924 - auc: 0.9984 - loss: 0.0582 - precision: 0.9971 - recall: 0.9874
# Epoch 7: val_loss improved from 0.17354 to 0.04769, saving model to outputs/CustomCNN_best.keras
#
# Epoch 7: finished saving model to outputs/CustomCNN_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9929 - auc: 0.9982 - loss: 0.0605 - precision: 0.9957 - recall: 0.9900 - val_accuracy: 0.9933 - val_auc: 1.0000 - val_loss: 0.0477 - val_precision: 0.9868 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 8/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9902 - auc: 0.9999 - loss: 0.0450 - precision: 0.9944 - recall: 0.9870
# Epoch 8: val_loss improved from 0.04769 to 0.03921, saving model to outputs/CustomCNN_best.keras
#
# Epoch 8: finished saving model to outputs/CustomCNN_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9921 - auc: 0.9999 - loss: 0.0436 - precision: 0.9943 - recall: 0.9900 - val_accuracy: 0.9967 - val_auc: 1.0000 - val_loss: 0.0392 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 0.0010
# Epoch 9/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9749 - auc: 0.9908 - loss: 0.1309 - precision: 0.9836 - recall: 0.9654
# Epoch 9: val_loss did not improve from 0.03921
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9764 - auc: 0.9929 - loss: 0.1159 - precision: 0.9812 - recall: 0.9714 - val_accuracy: 0.8800 - val_auc: 0.9933 - val_loss: 0.2887 - val_precision: 1.0000 - val_recall: 0.7600 - learning_rate: 0.0010
# Epoch 10/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9904 - auc: 0.9990 - loss: 0.0629 - precision: 0.9961 - recall: 0.9846
# Epoch 10: val_loss did not improve from 0.03921
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9907 - auc: 0.9986 - loss: 0.0674 - precision: 0.9957 - recall: 0.9857 - val_accuracy: 0.9900 - val_auc: 1.0000 - val_loss: 0.0496 - val_precision: 1.0000 - val_recall: 0.9800 - learning_rate: 0.0010
# Epoch 11/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9938 - auc: 0.9997 - loss: 0.0470 - precision: 0.9962 - recall: 0.9917
# Epoch 11: val_loss did not improve from 0.03921
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9929 - auc: 0.9996 - loss: 0.0468 - precision: 0.9957 - recall: 0.9900 - val_accuracy: 0.9733 - val_auc: 0.9933 - val_loss: 0.1180 - val_precision: 1.0000 - val_recall: 0.9467 - learning_rate: 0.0010
# Epoch 12/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9881 - auc: 0.9977 - loss: 0.0723 - precision: 0.9889 - recall: 0.9870
# Epoch 12: val_loss did not improve from 0.03921
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9850 - auc: 0.9955 - loss: 0.0998 - precision: 0.9899 - recall: 0.9800 - val_accuracy: 0.6867 - val_auc: 0.9367 - val_loss: 1.2900 - val_precision: 1.0000 - val_recall: 0.3733 - learning_rate: 0.0010
# Epoch 13/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9891 - auc: 0.9995 - loss: 0.0533 - precision: 0.9927 - recall: 0.9870
# Epoch 13: val_loss did not improve from 0.03921
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9914 - auc: 0.9995 - loss: 0.0501 - precision: 0.9914 - recall: 0.9914 - val_accuracy: 0.9300 - val_auc: 0.9867 - val_loss: 0.2719 - val_precision: 1.0000 - val_recall: 0.8600 - learning_rate: 5.0000e-04
# Epoch 14/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9937 - auc: 1.0000 - loss: 0.0368 - precision: 1.0000 - recall: 0.9869
# Epoch 14: val_loss did not improve from 0.03921
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9979 - auc: 1.0000 - loss: 0.0311 - precision: 1.0000 - recall: 0.9957 - val_accuracy: 0.9933 - val_auc: 1.0000 - val_loss: 0.0414 - val_precision: 1.0000 - val_recall: 0.9867 - learning_rate: 5.0000e-04
# Epoch 15/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9992 - auc: 1.0000 - loss: 0.0284 - precision: 0.9987 - recall: 0.9998
# Epoch 15: val_loss did not improve from 0.03921
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9971 - auc: 1.0000 - loss: 0.0301 - precision: 0.9986 - recall: 0.9957 - val_accuracy: 0.9900 - val_auc: 1.0000 - val_loss: 0.0508 - val_precision: 1.0000 - val_recall: 0.9800 - learning_rate: 5.0000e-04
# Epoch 16/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9975 - auc: 0.9997 - loss: 0.0339 - precision: 0.9971 - recall: 0.9980
# Epoch 16: val_loss did not improve from 0.03921
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9957 - auc: 0.9992 - loss: 0.0413 - precision: 0.9971 - recall: 0.9943 - val_accuracy: 0.9433 - val_auc: 0.9733 - val_loss: 0.3100 - val_precision: 1.0000 - val_recall: 0.8867 - learning_rate: 5.0000e-04
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 8.
#   Saved: outputs/fig_history_custom_cnn.png
#
# ============================================================
# Transfer Learning: VGG16
# ============================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# [Phase 1] Training classification head (base frozen)...
# Epoch 1/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8526 - auc: 0.9154 - loss: 0.5548 - precision: 0.8812 - recall: 0.8252
# Epoch 1: val_loss improved from None to 0.16155, saving model to outputs/TL_vgg16_phase1_best.keras
#
# Epoch 1: finished saving model to outputs/TL_vgg16_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 21s 161ms/step - accuracy: 0.9371 - auc: 0.9815 - loss: 0.2360 - precision: 0.9513 - recall: 0.9214 - val_accuracy: 0.9667 - val_auc: 0.9933 - val_loss: 0.1615 - val_precision: 1.0000 - val_recall: 0.9333 - learning_rate: 0.0010
# Epoch 2/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9792 - auc: 0.9973 - loss: 0.0909 - precision: 0.9868 - recall: 0.9717
# Epoch 2: val_loss improved from 0.16155 to 0.12194, saving model to outputs/TL_vgg16_phase1_best.keras
#
# Epoch 2: finished saving model to outputs/TL_vgg16_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.9821 - auc: 0.9983 - loss: 0.0804 - precision: 0.9856 - recall: 0.9786 - val_accuracy: 0.9733 - val_auc: 0.9967 - val_loss: 0.1219 - val_precision: 1.0000 - val_recall: 0.9467 - learning_rate: 0.0010
# Epoch 3/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9904 - auc: 0.9973 - loss: 0.0659 - precision: 0.9934 - recall: 0.9873
# Epoch 3: val_loss improved from 0.12194 to 0.04559, saving model to outputs/TL_vgg16_phase1_best.keras
#
# Epoch 3: finished saving model to outputs/TL_vgg16_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 0.9914 - auc: 0.9989 - loss: 0.0586 - precision: 0.9957 - recall: 0.9871 - val_accuracy: 0.9900 - val_auc: 1.0000 - val_loss: 0.0456 - val_precision: 1.0000 - val_recall: 0.9800 - learning_rate: 0.0010
# Epoch 4/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9922 - auc: 0.9994 - loss: 0.0504 - precision: 0.9904 - recall: 0.9943
# Epoch 4: val_loss did not improve from 0.04559
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.9914 - auc: 0.9991 - loss: 0.0561 - precision: 0.9928 - recall: 0.9900 - val_accuracy: 0.9833 - val_auc: 1.0000 - val_loss: 0.0837 - val_precision: 1.0000 - val_recall: 0.9667 - learning_rate: 0.0010
# Epoch 5/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9907 - auc: 0.9990 - loss: 0.0609 - precision: 0.9954 - recall: 0.9858
# Epoch 5: val_loss improved from 0.04559 to 0.03536, saving model to outputs/TL_vgg16_phase1_best.keras
#
# Epoch 5: finished saving model to outputs/TL_vgg16_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 0.9921 - auc: 0.9983 - loss: 0.0582 - precision: 0.9957 - recall: 0.9886 - val_accuracy: 0.9967 - val_auc: 1.0000 - val_loss: 0.0354 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 0.0010
# Epoch 6/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9946 - auc: 0.9989 - loss: 0.0557 - precision: 0.9927 - recall: 0.9968
# Epoch 6: val_loss did not improve from 0.03536
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.9957 - auc: 0.9990 - loss: 0.0517 - precision: 0.9943 - recall: 0.9971 - val_accuracy: 0.9800 - val_auc: 1.0000 - val_loss: 0.0653 - val_precision: 1.0000 - val_recall: 0.9600 - learning_rate: 0.0010
# Epoch 7/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9985 - auc: 1.0000 - loss: 0.0344 - precision: 0.9997 - recall: 0.9972
# Epoch 7: val_loss did not improve from 0.03536
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.9986 - auc: 1.0000 - loss: 0.0340 - precision: 0.9986 - recall: 0.9986 - val_accuracy: 0.9867 - val_auc: 1.0000 - val_loss: 0.0590 - val_precision: 1.0000 - val_recall: 0.9733 - learning_rate: 0.0010
# Epoch 8/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9992 - auc: 1.0000 - loss: 0.0334 - precision: 0.9996 - recall: 0.9988
# Epoch 8: val_loss did not improve from 0.03536
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.9979 - auc: 1.0000 - loss: 0.0350 - precision: 0.9986 - recall: 0.9971 - val_accuracy: 0.9733 - val_auc: 0.9933 - val_loss: 0.1159 - val_precision: 1.0000 - val_recall: 0.9467 - learning_rate: 0.0010
# Epoch 9/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9962 - auc: 0.9995 - loss: 0.0394 - precision: 0.9988 - recall: 0.9932
# Epoch 9: val_loss did not improve from 0.03536
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.9957 - auc: 0.9992 - loss: 0.0413 - precision: 0.9971 - recall: 0.9943 - val_accuracy: 0.9800 - val_auc: 0.9967 - val_loss: 0.1106 - val_precision: 1.0000 - val_recall: 0.9600 - learning_rate: 0.0010
# Epoch 10/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9989 - auc: 1.0000 - loss: 0.0312 - precision: 0.9989 - recall: 0.9989
# Epoch 10: val_loss did not improve from 0.03536
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.9971 - auc: 1.0000 - loss: 0.0325 - precision: 0.9971 - recall: 0.9971 - val_accuracy: 0.9867 - val_auc: 1.0000 - val_loss: 0.0463 - val_precision: 1.0000 - val_recall: 0.9733 - learning_rate: 5.0000e-04
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
#
# [Phase 2] Fine-tuning unfrozen base layers...
#   Fine-tuning: 13 frozen, 6 trainable layers in base
# Epoch 1/15
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9120 - auc: 0.9477 - loss: 0.6126 - precision: 0.9339 - recall: 0.8873
# Epoch 1: val_loss improved from None to 0.03675, saving model to outputs/TL_vgg16_best_best.keras
#
# Epoch 1: finished saving model to outputs/TL_vgg16_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 19s 143ms/step - accuracy: 0.9657 - auc: 0.9883 - loss: 0.2077 - precision: 0.9752 - recall: 0.9557 - val_accuracy: 0.9967 - val_auc: 1.0000 - val_loss: 0.0367 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 1.0000e-04
# Epoch 2/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0274 - precision: 1.0000 - recall: 1.0000
# Epoch 2: val_loss did not improve from 0.03675
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0271 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9967 - val_auc: 1.0000 - val_loss: 0.0412 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 1.0000e-04
# Epoch 3/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 0.0271 - precision: 1.0000 - recall: 0.9998
# Epoch 3: val_loss did not improve from 0.03675
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.9993 - auc: 1.0000 - loss: 0.0273 - precision: 1.0000 - recall: 0.9986 - val_accuracy: 0.9767 - val_auc: 0.9967 - val_loss: 0.1323 - val_precision: 1.0000 - val_recall: 0.9533 - learning_rate: 1.0000e-04
# Epoch 4/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9972 - auc: 0.9977 - loss: 0.0765 - precision: 1.0000 - recall: 0.9945
# Epoch 4: val_loss did not improve from 0.03675
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.9986 - auc: 0.9992 - loss: 0.0439 - precision: 1.0000 - recall: 0.9971 - val_accuracy: 0.9967 - val_auc: 0.9967 - val_loss: 0.0578 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 1.0000e-04
# Epoch 5/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0238 - precision: 1.0000 - recall: 1.0000
# Epoch 5: val_loss improved from 0.03675 to 0.02812, saving model to outputs/TL_vgg16_best_best.keras
#
# Epoch 5: finished saving model to outputs/TL_vgg16_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0235 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9967 - val_auc: 1.0000 - val_loss: 0.0281 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 1.0000e-04
# Epoch 6/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0226 - precision: 1.0000 - recall: 1.0000
# Epoch 6: val_loss did not improve from 0.02812
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0224 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9967 - val_auc: 0.9967 - val_loss: 0.0404 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 1.0000e-04
# Epoch 7/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0219 - precision: 1.0000 - recall: 1.0000
# Epoch 7: val_loss improved from 0.02812 to 0.02778, saving model to outputs/TL_vgg16_best_best.keras
#
# Epoch 7: finished saving model to outputs/TL_vgg16_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0217 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9967 - val_auc: 1.0000 - val_loss: 0.0278 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 1.0000e-04
# Epoch 8/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0213 - precision: 1.0000 - recall: 1.0000
# Epoch 8: val_loss did not improve from 0.02778
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0212 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9967 - val_auc: 1.0000 - val_loss: 0.0327 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 1.0000e-04
# Epoch 9/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0208 - precision: 1.0000 - recall: 1.0000
# Epoch 9: val_loss did not improve from 0.02778
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0206 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9967 - val_auc: 1.0000 - val_loss: 0.0333 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 1.0000e-04
# Epoch 10/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0203 - precision: 1.0000 - recall: 1.0000
# Epoch 10: val_loss did not improve from 0.02778
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0202 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9967 - val_auc: 1.0000 - val_loss: 0.0332 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 1.0000e-04
# Epoch 11/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0200 - precision: 1.0000 - recall: 1.0000
# Epoch 11: val_loss did not improve from 0.02778
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0199 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9967 - val_auc: 0.9967 - val_loss: 0.0557 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 1.0000e-04
# Epoch 12/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0195 - precision: 1.0000 - recall: 1.0000
# Epoch 12: val_loss did not improve from 0.02778
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0195 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9967 - val_auc: 0.9967 - val_loss: 0.0619 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 5.0000e-05
# Epoch 13/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0194 - precision: 1.0000 - recall: 1.0000
# Epoch 13: val_loss did not improve from 0.02778
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0193 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9967 - val_auc: 0.9967 - val_loss: 0.0613 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 5.0000e-05
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 7.
#   Saved: outputs/fig_history_vgg16.png
#
# ============================================================
# Transfer Learning: RESNET50
# ============================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#
# [Phase 1] Training classification head (base frozen)...
# Epoch 1/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9201 - auc: 0.9640 - loss: 0.2626 - precision: 0.9167 - recall: 0.9004
# Epoch 1: val_loss improved from None to 0.04321, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 1: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 30s 198ms/step - accuracy: 0.9779 - auc: 0.9972 - loss: 0.1096 - precision: 0.9813 - recall: 0.9743 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0432 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 2/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0400 - precision: 1.0000 - recall: 1.0000
# Epoch 2: val_loss improved from 0.04321 to 0.03721, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 2: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0391 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0372 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 3/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0364 - precision: 1.0000 - recall: 1.0000
# Epoch 3: val_loss improved from 0.03721 to 0.03396, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 3: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0354 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0340 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 4/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0331 - precision: 1.0000 - recall: 1.0000
# Epoch 4: val_loss improved from 0.03396 to 0.03122, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 4: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0324 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0312 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 5/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0307 - precision: 1.0000 - recall: 1.0000
# Epoch 5: val_loss improved from 0.03122 to 0.02843, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 5: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0299 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0284 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 6/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0280 - precision: 1.0000 - recall: 1.0000
# Epoch 6: val_loss improved from 0.02843 to 0.02629, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 6: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0274 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0263 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 7/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0258 - precision: 1.0000 - recall: 1.0000
# Epoch 7: val_loss improved from 0.02629 to 0.02452, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 7: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0254 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0245 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 8/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0238 - precision: 1.0000 - recall: 1.0000
# Epoch 8: val_loss improved from 0.02452 to 0.02238, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 8: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0233 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0224 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 9/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0219 - precision: 1.0000 - recall: 1.0000
# Epoch 9: val_loss improved from 0.02238 to 0.02070, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 9: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0215 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0207 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 10/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0202 - precision: 1.0000 - recall: 1.0000
# Epoch 10: val_loss improved from 0.02070 to 0.01925, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 10: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0198 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0193 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 11/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0189 - precision: 1.0000 - recall: 1.0000
# Epoch 11: val_loss improved from 0.01925 to 0.01770, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 11: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0187 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0177 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 12/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0174 - precision: 1.0000 - recall: 1.0000
# Epoch 12: val_loss improved from 0.01770 to 0.01637, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 12: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0171 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0164 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 13/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0161 - precision: 1.0000 - recall: 1.0000
# Epoch 13: val_loss improved from 0.01637 to 0.01517, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 13: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0159 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0152 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 14/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0149 - precision: 1.0000 - recall: 1.0000
# Epoch 14: val_loss improved from 0.01517 to 0.01401, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 14: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0146 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0140 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 15/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0138 - precision: 1.0000 - recall: 1.0000
# Epoch 15: val_loss improved from 0.01401 to 0.01308, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 15: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0136 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0131 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 16/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0128 - precision: 1.0000 - recall: 1.0000
# Epoch 16: val_loss improved from 0.01308 to 0.01200, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 16: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0125 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0120 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 17/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0118 - precision: 1.0000 - recall: 1.0000
# Epoch 17: val_loss improved from 0.01200 to 0.01112, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 17: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0116 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0111 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 18/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0110 - precision: 1.0000 - recall: 1.0000
# Epoch 18: val_loss improved from 0.01112 to 0.01027, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 18: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0108 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0103 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 19/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0101 - precision: 1.0000 - recall: 1.0000
# Epoch 19: val_loss improved from 0.01027 to 0.00950, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 19: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0099 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0095 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 20/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0093 - precision: 1.0000 - recall: 1.0000
# Epoch 20: val_loss improved from 0.00950 to 0.00882, saving model to outputs/TL_resnet50_phase1_best.keras
#
# Epoch 20: finished saving model to outputs/TL_resnet50_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0092 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0088 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 20.
#
# [Phase 2] Fine-tuning unfrozen base layers...
#   Fine-tuning: 160 frozen, 15 trainable layers in base
# Epoch 1/15
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0087 - precision: 1.0000 - recall: 1.0000
# Epoch 1: val_loss improved from None to 0.00772, saving model to outputs/TL_resnet50_best_best.keras
#
# Epoch 1: finished saving model to outputs/TL_resnet50_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 34s 208ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0082 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0077 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 2/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0069 - precision: 1.0000 - recall: 1.0000
# Epoch 2: val_loss improved from 0.00772 to 0.00637, saving model to outputs/TL_resnet50_best_best.keras
#
# Epoch 2: finished saving model to outputs/TL_resnet50_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0067 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0064 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 3/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0061 - precision: 1.0000 - recall: 1.0000
# Epoch 3: val_loss improved from 0.00637 to 0.00561, saving model to outputs/TL_resnet50_best_best.keras
#
# Epoch 3: finished saving model to outputs/TL_resnet50_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0059 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0056 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 4/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0055 - precision: 1.0000 - recall: 1.0000
# Epoch 4: val_loss improved from 0.00561 to 0.00513, saving model to outputs/TL_resnet50_best_best.keras
#
# Epoch 4: finished saving model to outputs/TL_resnet50_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0055 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0051 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 5/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0055 - precision: 1.0000 - recall: 1.0000
# Epoch 5: val_loss did not improve from 0.00513
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9993 - auc: 0.9993 - loss: 0.0095 - precision: 1.0000 - recall: 0.9986 - val_accuracy: 0.8467 - val_auc: 0.9467 - val_loss: 0.8657 - val_precision: 1.0000 - val_recall: 0.6933 - learning_rate: 1.0000e-04
# Epoch 6/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0079 - precision: 1.0000 - recall: 1.0000
# Epoch 6: val_loss did not improve from 0.00513
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0060 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9933 - val_auc: 1.0000 - val_loss: 0.0186 - val_precision: 1.0000 - val_recall: 0.9867 - learning_rate: 1.0000e-04
# Epoch 7/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9996 - auc: 1.0000 - loss: 0.0059 - precision: 0.9997 - recall: 0.9995
# Epoch 7: val_loss did not improve from 0.00513
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9986 - auc: 1.0000 - loss: 0.0087 - precision: 0.9986 - recall: 0.9986 - val_accuracy: 0.8800 - val_auc: 0.9200 - val_loss: 1.4664 - val_precision: 1.0000 - val_recall: 0.7600 - learning_rate: 1.0000e-04
# Epoch 8/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0053 - precision: 1.0000 - recall: 1.0000
# Epoch 8: val_loss did not improve from 0.00513
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0053 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9967 - val_auc: 1.0000 - val_loss: 0.0169 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 1.0000e-04
# Epoch 9/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0047 - precision: 1.0000 - recall: 1.0000
# Epoch 9: val_loss improved from 0.00513 to 0.00461, saving model to outputs/TL_resnet50_best_best.keras
#
# Epoch 9: finished saving model to outputs/TL_resnet50_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0047 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0046 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Epoch 10/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0046 - precision: 1.0000 - recall: 1.0000
# Epoch 10: val_loss improved from 0.00461 to 0.00455, saving model to outputs/TL_resnet50_best_best.keras
#
# Epoch 10: finished saving model to outputs/TL_resnet50_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0046 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0046 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Epoch 11/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0046 - precision: 1.0000 - recall: 1.0000
# Epoch 11: val_loss improved from 0.00455 to 0.00451, saving model to outputs/TL_resnet50_best_best.keras
#
# Epoch 11: finished saving model to outputs/TL_resnet50_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0046 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0045 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Epoch 12/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0045 - precision: 1.0000 - recall: 1.0000
# Epoch 12: val_loss improved from 0.00451 to 0.00446, saving model to outputs/TL_resnet50_best_best.keras
#
# Epoch 12: finished saving model to outputs/TL_resnet50_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0045 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0045 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Epoch 13/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0045 - precision: 1.0000 - recall: 1.0000
# Epoch 13: val_loss improved from 0.00446 to 0.00441, saving model to outputs/TL_resnet50_best_best.keras
#
# Epoch 13: finished saving model to outputs/TL_resnet50_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0045 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0044 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Epoch 14/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 0.0048 - precision: 1.0000 - recall: 0.9999
# Epoch 14: val_loss improved from 0.00441 to 0.00435, saving model to outputs/TL_resnet50_best_best.keras
#
# Epoch 14: finished saving model to outputs/TL_resnet50_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 0.9993 - auc: 1.0000 - loss: 0.0051 - precision: 1.0000 - recall: 0.9986 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0044 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Epoch 15/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0045 - precision: 1.0000 - recall: 1.0000
# Epoch 15: val_loss improved from 0.00435 to 0.00431, saving model to outputs/TL_resnet50_best_best.keras
#
# Epoch 15: finished saving model to outputs/TL_resnet50_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0045 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0043 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 15.
#   Saved: outputs/fig_history_resnet50.png
#
# ============================================================
# Transfer Learning: MOBILENETV2
# ============================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# [Phase 1] Training classification head (base frozen)...
# Epoch 1/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9339 - auc: 0.9640 - loss: 0.1953 - precision: 0.9289 - recall: 0.9519
# Epoch 1: val_loss improved from None to 0.04216, saving model to outputs/TL_mobilenetv2_phase1_best.keras
#
# Epoch 1: finished saving model to outputs/TL_mobilenetv2_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 36s 261ms/step - accuracy: 0.9814 - auc: 0.9987 - loss: 0.0877 - precision: 0.9787 - recall: 0.9843 - val_accuracy: 0.9967 - val_auc: 1.0000 - val_loss: 0.0422 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 0.0010
# Epoch 2/20
# ...
# Epoch 13/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0177 - precision: 1.0000 - recall: 1.0000
# Epoch 13: val_loss improved from 0.01946 to 0.01881, saving model to outputs/TL_mobilenetv2_phase1_best.keras
#
# Epoch 13: finished saving model to outputs/TL_mobilenetv2_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0174 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0188 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 14/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0165 - precision: 1.0000 - recall: 1.0000
# Epoch 14: val_loss did not improve from 0.01881
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0162 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9967 - val_auc: 1.0000 - val_loss: 0.0196 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 0.0010
# Epoch 15/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0152 - precision: 1.0000 - recall: 1.0000
# Epoch 15: val_loss improved from 0.01881 to 0.01614, saving model to outputs/TL_mobilenetv2_phase1_best.keras
#
# Epoch 15: finished saving model to outputs/TL_mobilenetv2_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0149 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0161 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 16/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0140 - precision: 1.0000 - recall: 1.0000
# Epoch 16: val_loss did not improve from 0.01614
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0143 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9967 - val_auc: 1.0000 - val_loss: 0.0290 - val_precision: 1.0000 - val_recall: 0.9933 - learning_rate: 0.0010
# Epoch 17/20
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9995 - auc: 1.0000 - loss: 0.0146 - precision: 0.9996 - recall: 0.9994
# Epoch 17: val_loss did not improve from 0.01614
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9986 - auc: 1.0000 - loss: 0.0157 - precision: 0.9986 - recall: 0.9986 - val_accuracy: 0.9933 - val_auc: 1.0000 - val_loss: 0.0382 - val_precision: 1.0000 - val_recall: 0.9867 - learning_rate: 0.0010
# Epoch 18/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9983 - auc: 1.0000 - loss: 0.0166 - precision: 1.0000 - recall: 0.9965
# Epoch 18: val_loss improved from 0.01614 to 0.01326, saving model to outputs/TL_mobilenetv2_phase1_best.keras
#
# Epoch 18: finished saving model to outputs/TL_mobilenetv2_phase1_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9993 - auc: 1.0000 - loss: 0.0155 - precision: 1.0000 - recall: 0.9986 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0133 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 19/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9946 - auc: 0.9984 - loss: 0.0444 - precision: 0.9943 - recall: 0.9951
# Epoch 19: val_loss did not improve from 0.01326
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9950 - auc: 0.9992 - loss: 0.0348 - precision: 0.9957 - recall: 0.9943 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0159 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 20/20
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9901 - auc: 0.9943 - loss: 0.0741 - precision: 0.9868 - recall: 0.9934
# Epoch 20: val_loss did not improve from 0.01326
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9921 - auc: 0.9956 - loss: 0.0655 - precision: 0.9900 - recall: 0.9943 - val_accuracy: 0.9800 - val_auc: 0.9933 - val_loss: 0.1272 - val_precision: 1.0000 - val_recall: 0.9600 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 18.
#
# [Phase 2] Fine-tuning unfrozen base layers...
#   Fine-tuning: 134 frozen, 20 trainable layers in base
# Epoch 1/15
# 2026-06-27 21:35:11.644665: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-27 21:35:11.841055: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9857 - auc: 0.9943 - loss: 0.0921 - precision: 0.9945 - recall: 0.9777
# Epoch 1: val_loss improved from None to 0.01374, saving model to outputs/TL_mobilenetv2_best_best.keras
#
# Epoch 1: finished saving model to outputs/TL_mobilenetv2_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 35s 225ms/step - accuracy: 0.9886 - auc: 0.9976 - loss: 0.0532 - precision: 0.9886 - recall: 0.9886 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0137 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 2/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9956 - auc: 0.9991 - loss: 0.0288 - precision: 0.9988 - recall: 0.9921
# Epoch 2: val_loss improved from 0.01374 to 0.01140, saving model to outputs/TL_mobilenetv2_best_best.keras
#
# Epoch 2: finished saving model to outputs/TL_mobilenetv2_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9957 - auc: 0.9985 - loss: 0.0315 - precision: 0.9971 - recall: 0.9943 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0114 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 3/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9877 - auc: 0.9965 - loss: 0.0612 - precision: 0.9841 - recall: 0.9926
# Epoch 3: val_loss did not improve from 0.01140
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9900 - auc: 0.9962 - loss: 0.0630 - precision: 0.9872 - recall: 0.9929 - val_accuracy: 0.9967 - val_auc: 1.0000 - val_loss: 0.0141 - val_precision: 0.9934 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 4/15
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9961 - auc: 0.9991 - loss: 0.0245 - precision: 0.9987 - recall: 0.9936
# Epoch 4: val_loss improved from 0.01140 to 0.01087, saving model to outputs/TL_mobilenetv2_best_best.keras
#
# Epoch 4: finished saving model to outputs/TL_mobilenetv2_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9957 - auc: 0.9985 - loss: 0.0247 - precision: 0.9971 - recall: 0.9943 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0109 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 5/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9986 - auc: 0.9999 - loss: 0.0144 - precision: 0.9998 - recall: 0.9974
# Epoch 5: val_loss did not improve from 0.01087
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9971 - auc: 0.9993 - loss: 0.0206 - precision: 0.9986 - recall: 0.9957 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0111 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 6/15
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9937 - auc: 1.0000 - loss: 0.0279 - precision: 0.9907 - recall: 0.9965
# Epoch 6: val_loss did not improve from 0.01087
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 0.0217 - precision: 0.9957 - recall: 0.9957 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0124 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 7/15
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9991 - auc: 1.0000 - loss: 0.0120 - precision: 0.9994 - recall: 0.9987
# Epoch 7: val_loss did not improve from 0.01087
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9964 - auc: 1.0000 - loss: 0.0162 - precision: 0.9943 - recall: 0.9986 - val_accuracy: 0.9967 - val_auc: 1.0000 - val_loss: 0.0133 - val_precision: 0.9934 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 8/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9938 - auc: 0.9999 - loss: 0.0246 - precision: 0.9990 - recall: 0.9891
# Epoch 8: val_loss improved from 0.01087 to 0.01056, saving model to outputs/TL_mobilenetv2_best_best.keras
#
# Epoch 8: finished saving model to outputs/TL_mobilenetv2_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9964 - auc: 0.9993 - loss: 0.0219 - precision: 0.9986 - recall: 0.9943 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0106 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 9/15
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9962 - auc: 0.9983 - loss: 0.0305 - precision: 0.9954 - recall: 0.9969
# Epoch 9: val_loss improved from 0.01056 to 0.01049, saving model to outputs/TL_mobilenetv2_best_best.keras
#
# Epoch 9: finished saving model to outputs/TL_mobilenetv2_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9907 - auc: 0.9941 - loss: 0.0688 - precision: 0.9942 - recall: 0.9871 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0105 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 10/15
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9866 - auc: 0.9977 - loss: 0.0596 - precision: 0.9778 - recall: 0.9954
# Epoch 10: val_loss improved from 0.01049 to 0.01042, saving model to outputs/TL_mobilenetv2_best_best.keras
#
# Epoch 10: finished saving model to outputs/TL_mobilenetv2_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.9893 - auc: 0.9984 - loss: 0.0491 - precision: 0.9872 - recall: 0.9914 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0104 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 11/15
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9982 - auc: 1.0000 - loss: 0.0154 - precision: 0.9963 - recall: 1.0000
# Epoch 11: val_loss improved from 0.01042 to 0.01037, saving model to outputs/TL_mobilenetv2_best_best.keras
#
# Epoch 11: finished saving model to outputs/TL_mobilenetv2_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9993 - auc: 1.0000 - loss: 0.0126 - precision: 0.9986 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0104 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 12/15
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9992 - auc: 1.0000 - loss: 0.0130 - precision: 0.9995 - recall: 0.9990
# Epoch 12: val_loss improved from 0.01037 to 0.01033, saving model to outputs/TL_mobilenetv2_best_best.keras
#
# Epoch 12: finished saving model to outputs/TL_mobilenetv2_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9986 - auc: 1.0000 - loss: 0.0149 - precision: 0.9986 - recall: 0.9986 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0103 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 13/15
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9998 - auc: 1.0000 - loss: 0.0116 - precision: 0.9996 - recall: 1.0000
# Epoch 13: val_loss improved from 0.01033 to 0.01028, saving model to outputs/TL_mobilenetv2_best_best.keras
#
# Epoch 13: finished saving model to outputs/TL_mobilenetv2_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9993 - auc: 1.0000 - loss: 0.0120 - precision: 0.9986 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0103 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 14/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9990 - auc: 1.0000 - loss: 0.0118 - precision: 0.9979 - recall: 1.0000
# Epoch 14: val_loss improved from 0.01028 to 0.01023, saving model to outputs/TL_mobilenetv2_best_best.keras
#
# Epoch 14: finished saving model to outputs/TL_mobilenetv2_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9993 - auc: 1.0000 - loss: 0.0113 - precision: 0.9986 - recall: 1.0000 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0102 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 15/15
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9987 - auc: 0.9992 - loss: 0.0191 - precision: 0.9985 - recall: 0.9990
# Epoch 15: val_loss improved from 0.01023 to 0.01017, saving model to outputs/TL_mobilenetv2_best_best.keras
#
# Epoch 15: finished saving model to outputs/TL_mobilenetv2_best_best.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9986 - auc: 0.9993 - loss: 0.0190 - precision: 0.9986 - recall: 0.9986 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0102 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 15.
#   Saved: outputs/fig_history_mobilenetv2.png
#
# [Evaluating all models on test set...]
#   Saved: outputs/fig_cm_custom_cnn.png
#   Saved: outputs/fig_cm_vgg16.png
#   Saved: outputs/fig_cm_resnet50.png
#   Saved: outputs/fig_cm_mobilenetv2.png
#
# ============================================================
# Classification Reports
# ============================================================
#
# --- Custom CNN ---
#               precision    recall  f1-score   support
#
#        Fresh       0.99      1.00      1.00       150
#    Non-Fresh       1.00      0.99      1.00       150
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
#
# --- VGG16 ---
#               precision    recall  f1-score   support
#
#        Fresh       1.00      1.00      1.00       150
#    Non-Fresh       1.00      1.00      1.00       150
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
#
# --- ResNet50 ---
#               precision    recall  f1-score   support
#
#        Fresh       1.00      1.00      1.00       150
#    Non-Fresh       1.00      1.00      1.00       150
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
#
# --- MobileNetV2 ---
#               precision    recall  f1-score   support
#
#        Fresh       1.00      1.00      1.00       150
#    Non-Fresh       1.00      1.00      1.00       150
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
#
# ============================================================
# Model Comparison Table
# ============================================================
#       Model  Accuracy  Precision  Recall  F1-Score  AUC-ROC
#  Custom CNN    0.9967        1.0  0.9933    0.9967      1.0
#       VGG16    1.0000        1.0  1.0000    1.0000      1.0
#    ResNet50    1.0000        1.0  1.0000    1.0000      1.0
# MobileNetV2    1.0000        1.0  1.0000    1.0000      1.0
#   Saved: outputs/fig_model_comparison.png
#   Saved: outputs/fig_roc_curves.png
#   Saved: outputs/fig_gradcam_custom_cnn.png
# [WARN] Grad-CAM failed for ResNet50: No such layer: conv5_block3_out. Existing layers are: ['input', 'preprocess', 'resnet50', 'gap', 'dense1', 'dropout', 'output'].
#   Saved: outputs/fig_error_analysis_custom_cnn.png
#   Total errors: 1 of 300
#   No errors found for ResNet50.
#
# [Saving models...]
#   All models saved.
#
# ============================================================
# FINAL RESULTS SUMMARY
# ============================================================
#       Model  Accuracy  Precision  Recall  F1-Score  AUC-ROC
#  Custom CNN    0.9967        1.0  0.9933    0.9967      1.0
#       VGG16    1.0000        1.0  1.0000    1.0000      1.0
#    ResNet50    1.0000        1.0  1.0000    1.0000      1.0
# MobileNetV2    1.0000        1.0  1.0000    1.0000      1.0
#
#   Best model by F1-Score: VGG16 (F1 = 1.0000)
#
#   All output figures saved to: /kaggle/working/outputs
# ============================================================
# Done!
